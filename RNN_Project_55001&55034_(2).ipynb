# %% [markdown]
# # **Project Report: Sentiment Analysis Using Recurrent Neural Networks (RNN)**

# %% [markdown]
# ## **1. Project Information**
#
# **Project Title:** Sentiment Analysis of
# Metacritic's Best Movies and Reviews - 2025
#
# **Developed by:** Aayush Garg (055001) and Priyanka Goyal (055034)
#
# **Technology Stack:** Python, TensorFlow, Keras, LSTM (RNN), Streamlit
#
# **Data Source:** [Best Movies & Reviews Dataset](https://drive.google.com/file/d/1UrRS2NfAfb0Agcf8jyJjvVdbmWkZPGay/view?usp=drive_link)
#
# **Model Type:** Recurrent Neural Network (RNN)

# %% [markdown]
# ## **2. Description of Data**
#
# **Dataset:** Metacritic Movies and Reviews
#
# **Movies:** 16K+
#
# **Reviews:** 667K+ (Critic & User)
#
# **Includes:** Ratings, genres, directors, cast, sentiment scores
#
# **Focus:** Movies from Metacritic’s Best Movies of All Time list
#
# **Uses:** Sentiment analysis, rating prediction, trend analysis
#
# **Preprocessing Steps:**
#
# - Cleaning: Removed null values, special characters, and extra spaces.
#
# - Text Processing: Tokenization, stopword removal, lemmatization.
#
# - Encoding: Converted sentiment labels to numeric, tokenized text.
#
# - Splitting: 80-20% train-test split.

# %% [markdown]
# ## **3. Project Objective and Problem Statements**
#
# **Objective:**
#
# To build an RNN-based sentiment analysis model that classifies movie reviews as positive or negative using LSTM networks. This will help businesses and platforms analyze audience feedback more effectively, enabling better decision-making for content curation, marketing strategies, and customer engagement.
#
# **Problem Statement:**
#
# Understanding customer sentiment is essential for businesses to track opinions and market trends. With the increasing reliance on online reviews, businesses need automated tools to analyze customer feedback at scale and derive actionable insights.
#
# Traditional NLP approaches struggle with capturing context and long-term dependencies in text, leading to inaccuracies in sentiment classification. This makes it challenging for marketing teams to gauge audience perception accurately and adjust promotional strategies accordingly.
#
# Basic RNN models face limitations like the vanishing gradient problem, making them ineffective for long sequences. This results in loss of critical contextual information, hindering businesses from obtaining a deep understanding of consumer preferences and behavior.
#
# LSTM networks overcome these challenges by preserving sequential dependencies, leading to improved sentiment classification accuracy. By leveraging LSTM models, businesses can:
#
# - Enhance product and service positioning by understanding customer emotions and preferences.
# - Optimize targeted marketing campaigns based on audience sentiment trends.
# - Improve brand reputation management by identifying negative feedback early and responding proactively.
# - Personalize content recommendations for streaming platforms, increasing user engagement and retention.
#
# ## **4. Data Analysis**
#
# Each entry includes:
#
# - **Movie details** – title, genre, director, cast, and release year.
# - **Review data** – user reviews, critic reviews, and sentiment ratings.
#
# **Key Insights from Data:**
#
# - **Sentiment Distribution:**
#   - The dataset contains both positive and negative reviews, with some neutral opinions.
#   - A higher number of reviews show a slight bias toward either extreme sentiments, affecting business decisions like audience targeting and content adaptation.
#
# - **Review Length Analysis:**
#   - Positive reviews tend to be longer, with detailed explanations, often providing deeper insights for content marketers.
#   - Negative reviews are often shorter and direct, focusing on key issues, making them crucial for customer service teams in addressing concerns promptly.
#
# - **Rating Trends:**
#   - User ratings often differ from critic ratings, showing varied audience perceptions, which can help businesses fine-tune marketing messaging.
#   - Certain genres, like drama and thriller, receive more polarized reviews, aiding production studios and marketers in positioning their films more effectively.
#
# By analyzing these insights, businesses can refine their content strategies, improve user experience, and make data-driven marketing decisions.

# %% [markdown]
# ## **5. Model Selection**
#
# - RNNs struggle with long-term dependencies; LSTMs handle them better, making them ideal for sentiment analysis.
#
# - Traditional models (SVM, Logistic Regression) fail to capture word order and context effectively.
#
# - Model Architecture
#   - Embedding Layer: Converts words into dense vectors.
#
#   - LSTM Layers (64 & 32 units): Learn sequential patterns.
#
#   - Dropout (0.5): Prevents overfitting.
#
# - Optimization
#   - Loss: MSE (for continuous sentiment scores).
#
#   - Optimizer: Adam (efficient learning).
#
#   - Metric: MAE (measures prediction accuracy).

# %% [markdown]
# ## **6. Observations and Findings**
#
# ### **Model Performance Overview**
#
# - **Test MAE: 0.7515** – This indicates that, on average, the model's predictions deviate by 0.75 sentiment points from the actual sentiment scores. While not ideal, it suggests the model is learning to some extent and can be fine-tuned for better accuracy. Businesses relying on automated sentiment analysis should consider improving data preprocessing and hyperparameter tuning to enhance predictive performance.
#
# ### **Class Imbalance:**
#
# - The model shows a tendency to predict neutral sentiment (Class 0) more often, which is likely due to the class imbalance in the dataset. This can impact businesses that rely on sentiment analysis for customer insights, as extreme positive or negative sentiments drive key marketing and brand management decisions.
#
# - It struggles with extreme sentiments (Overwhelming Dislike (-2) & Universal Acclaim (2)), often misclassifying them. This is crucial for businesses since highly negative reviews may indicate serious customer dissatisfaction requiring immediate action, while highly positive reviews can serve as powerful testimonials for marketing campaigns.
#
# ### **Confusion Matrix:**
#
# - The confusion matrix reveals that the model has the most difficulty distinguishing between adjacent sentiment classes (e.g., -1 and 0, 0 and 1). For businesses, this could lead to challenges in accurately assessing audience sentiment trends, potentially leading to suboptimal product positioning.
#
# - It often predicts neutral sentiment when the actual sentiment is slightly positive or negative. This could mislead businesses into believing customer sentiment is more balanced than it actually is, impacting content strategies and brand messaging.
#
# ### **Classification Report:**
#
# - The classification report confirms the model's relatively low precision and recall for extreme sentiments (-2 and 2), indicating it struggles to identify these categories accurately. This is a challenge for brands that depend on sentiment extremes to assess product success or failure.
#
# - The weighted F1-score is relatively low, highlighting the overall suboptimal performance, especially for non-neutral sentiments. Businesses using this model for customer sentiment analysis should incorporate techniques like data augmentation or class weighting to address imbalances.
#
# ### **Key Challenges:**
#
# - **Severe Class Imbalance:** The dataset has a significant bias towards neutral reviews, which hinders the model's ability to learn and generalize well for extreme sentiments. This can affect businesses by distorting customer satisfaction metrics, leading to flawed marketing strategies.
#
# - **Potential Overfitting:** The model might be overfitting to the training data, as indicated by the relatively good training performance but lower test performance. For businesses, this could mean inaccurate sentiment predictions when analyzing real-world customer feedback.
#
# - **Data Representation Limitations:** The current tokenization and padding approach may not fully capture the contextual nuances and complexities of sentiment in movie reviews. This limitation could lead to misinterpretation of audience sentiment, affecting decision-making in advertising, branding, and customer engagement strategies.
#
# By addressing these challenges, businesses can refine their sentiment analysis models to better understand audience feedback, enhance marketing strategies, and improve customer experience.

# %% [markdown]
# ## **7. Findings from Visualizations and Training Process Analysis**
#
# ### **Insights from Visualizations**
#
# - **Sentiment Score Distribution:**
#   - The dataset exhibits a class imbalance, with a majority of reviews falling into neutral (0) and positive (1) categories, while extreme sentiments (-2, 2) are less frequent. This imbalance is confirmed by the distribution plots generated using seaborn.
#   - For businesses, this imbalance can influence automated sentiment analysis in areas like customer feedback management and market research.
#
# - **Predicted vs. Actual Sentiment Scores:**
#   - Visualizations comparing predicted and actual sentiment scores reveal that the model struggles with accurately predicting extreme sentiments, tending to cluster predictions around neutral and positive values.
#   - This limitation can affect brands trying to gauge customer dissatisfaction early to mitigate negative publicity.
#
# - **Word Frequency Analysis:**
#   - Analysis of word frequencies highlights clear distinctions between positive and negative words. However, there's an overlap of certain neutral words across categories, potentially contributing to the model's difficulty in distinguishing subtle sentiment variations.
#   - Businesses can use these insights to refine keyword-based sentiment tracking tools for digital marketing.
#
# - **Training vs. Validation Loss & MAE:**
#   - The training process reveals signs of overfitting, especially after Epoch 3, where validation loss increases while training loss continues to decrease. This divergence indicates that the model is learning the training data too well and may not generalize effectively to unseen data.
#   - In marketing applications, this could lead to misleading insights when analyzing customer feedback from new campaigns.
#
# ### **Model Training and Performance Analysis**
#
# - **Training Progression:** The training process shows a general decrease in loss and MAE over epochs. However, the increasing generalization gap between training and validation metrics suggests overfitting.
#
# - **Key Epochs:**
#   - **Epoch 1:** Loss = 0.8160, MAE = 0.7603 (Initial learning phase)
#   - **Epoch 3:** Loss = 0.7215, MAE = 0.6925 (Best generalization, before overfitting becomes prominent)
#   - **Epoch 5:** Loss = 0.6412, MAE = 0.6161 (Overfitting evident)
#
# ### **Challenges and Recommendations**
#
# - **Class Imbalance:** Address imbalance using techniques like oversampling (SMOTE) or weighted loss functions. This can help businesses extract more accurate insights from customer sentiment data.
# - **Overfitting Mitigation:** Implement early stopping, dropout layers, and L2 regularization to improve model generalization, ensuring reliable sentiment analysis for marketing insights.
# - **Sentiment Representation:** Explore using pre-trained embeddings like BERT or Word2Vec for richer semantic understanding, crucial for marketing sentiment analysis.
# - **Hyperparameter Optimization:** Tune learning rates, optimizers, and activation functions to improve model performance, ensuring better accuracy in customer sentiment prediction.

# %% [markdown]
# ## **8. Managerial Insights & Recommendations**
#
# ### **Key Insights:**
# - **Sentiment Trends & Market Perception:** The model’s limitations in extreme sentiment detection require businesses to use its insights cautiously.
# - **Challenges in Nuance Detection:** Sarcasm and mixed sentiment reviews remain difficult for the model.
# - **Potential Overfitting Issues:** Reducing overfitting ensures better generalization for real-world applications.
#
# ### **Recommendations for Business & Marketing:**
# - **Refine Sentiment Detection:** Improve handling of sarcasm, mixed reviews, and emotional intensities.
# - **Address Class Imbalance:** Implement rebalancing techniques for fairer sentiment classification.
# - **Improve Data Representation:** Leverage advanced NLP techniques for better contextual understanding.
# - **Optimize Targeted Marketing:** Use sentiment insights to adjust branding strategies and customer engagement.
# - **Enhance Brand Reputation Management:** Identify negative trends early for proactive resolution.
# - **Align User & Critic Perceptions:** Identify discrepancies between critic and user sentiment to refine marketing efforts.
#
# By implementing these strategies, businesses can maximize the value of sentiment analysis, leading to improved customer engagement, more precise market positioning, and optimized content strategies.

# %% [markdown]
# ## **Conclusion**
#
# This project explored sentiment analysis using an RNN with LSTM layers to classify movie reviews. While the model achieved a test MAE of 0.7515, its performance was limited by class imbalance and overfitting.
#
# ### **Future Directions:**
#
# - **Enhance Sentiment Representation:** Implement advanced embeddings like BERT for improved sentiment prediction.
# - **Refine Model for Business Applications:** Fine-tune hyperparameters and implement data balancing techniques for better accuracy.
# - **Leverage Sentiment Insights for Strategic Decision-Making:** Use refined sentiment analysis for brand reputation management and customer engagement strategies.
#
# By addressing these challenges, businesses can transform sentiment analysis into a valuable tool for market intelligence, targeted marketing, and audience engagement.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from google.colab import drive
import gdown


# Download the file from Google Drive
pg34_file_url = 'https://drive.google.com/uc?id=1UrRS2NfAfb0Agcf8jyJjvVdbmWkZPGay'
pg34_file_path = '/content/movies.csv'
gdown.download(pg34_file_url, pg34_file_path, quiet=False)

pg34_df = pd.read_csv(pg34_file_path)
print(pg34_df.head())

# Drop missing values
pg34_df.dropna(subset=['description', 'metascore_sentiment'], inplace=True)

# Use movie descriptions as text and metascore_sentiment as labels
pg34_texts = pg34_df['description'].astype(str).values
pg34_labels = pg34_df['metascore_sentiment'].values

# Convert sentiment labels to numeric values
pg34_sentiment_mapping = {'Universal acclaim': 2, 'Generally favorable': 1, 'Mixed or average': 0, 'Generally unfavorable': -1, 'Overwhelming dislike': -2}
pg34_labels = np.array([pg34_sentiment_mapping[label] for label in pg34_labels if label in pg34_sentiment_mapping])

# Tokenization and padding
max_words = 10000  # Vocabulary size
max_len = 100  # Max sequence length

tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(pg34_texts)
sequences = tokenizer.texts_to_sequences(pg34_texts)
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post', truncating='post')

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, pg34_labels, test_size=0.2, random_state=550134)

# Define the RNN model
model = Sequential([
    Embedding(input_dim=max_words, output_dim=64, input_length=max_len),
    LSTM(64, return_sequences=True),
    LSTM(32),
    Dropout(0.5),
    Dense(1, activation='tanh')  # Adjust activation based on sentiment range
])

# Compile the model
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# Train the model
epochs = 5
batch_size = 32
model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))

# Evaluate the model
loss, mae = model.evaluate(X_test, y_test)
print(f"Test MAE: {mae:.4f}")

# Predict sentiment for new descriptions
def predict_sentiment(text):
    sequence = tokenizer.texts_to_sequences([text])
    padded = pad_sequences(sequence, maxlen=max_len, padding='post', truncating='post')
    prediction = model.predict(padded)[0][0]
    return prediction

# Example usage
sample_text = "A gripping and emotional drama with outstanding performances."
print(f"Predicted Sentiment Score: {predict_sentiment(sample_text)}")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UrRS2NfAfb0Agcf8jyJjvVdbmWkZPGay
# To: /content/movies.csv
# 100%|██████████| 22.9M/22.9M [00:00<00:00, 105MB/s]
#            id                     title releaseDate rating  \
# 0  2000545497            Dekalog (1988)  1996-03-22  TV-MA
# 1  2000521589  The Leopard (re-release)  2004-08-13     PG
# 2  2000548059               Rear Window  1954-09-01  TV-PG
# 3  2000542176                   Boyhood  2014-07-11  TV-14
# 4  2000545507         Three Colors: Red  1994-11-23      R
#
#                    genres                                        description  \
# 0                   Drama  This masterwork by Krzysztof Kieślowski is one...
# 1           Drama,History  Set in Sicily in 1860, Luchino Visconti's spec...
# 2  Drama,Mystery,Thriller  A wheelchair-bound photographer spies on his n...
# 3                   Drama  Filmed over 12 years with the same cast, Richa...
# ...

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import itertools

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot sentiment distribution
plt.figure(figsize=(8, 5))
sns.histplot(y_train, bins=5, kde=True, label='Train', color='blue', alpha=0.6)
sns.histplot(y_test, bins=5, kde=True, label='Test', color='red', alpha=0.6)
plt.title("Sentiment Score Distribution in Train and Test Data")
plt.xlabel("Sentiment Score")
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
# Visualizing sample predictions
sample_texts = [
    "A fantastic and thrilling adventure!",
    "The worst movie I have ever seen.",
    "It was okay, nothing special but not bad either.",
    "An emotional rollercoaster with outstanding performances.",
    "Boring and slow-paced, not engaging at all."
]
sample_predictions = [predict_sentiment(text) for text in sample_texts]

plt.figure(figsize=(8, 5))
sns.barplot(x=sample_predictions, y=sample_texts, orient='h', palette='coolwarm')
plt.xlabel("Predicted Sentiment Score")
plt.ylabel("Movie Review")
plt.title("Sample Sentiment Predictions")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# <ipython-input-7-10e74048be06>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sample_predictions, y=sample_texts, orient='h', palette='coolwarm')

# %%
# Generate predictions for test set
y_pred = model.predict(X_test)
y_pred_rounded = np.round(y_pred).flatten()

# Confusion Matrix
def plot_confusion_matrix(y_true, y_pred, classes):
    cm = confusion_matrix(y_true, y_pred, labels=classes)
    plt.figure(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

plot_confusion_matrix(y_test, y_pred_rounded, classes=np.unique(y_test))
# Out:
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step

# %%
from sklearn.metrics import classification_report
# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred_rounded))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#           -2       0.00      0.00      0.00        30
#           -1       0.18      0.01      0.02       372
#            0       0.39      0.65      0.49      1130
#            1       0.50      0.50      0.50      1424
#            2       0.00      0.00      0.00       350
#
#     accuracy                           0.44      3306
#    macro avg       0.21      0.23      0.20      3306
# weighted avg       0.37      0.44      0.38      3306
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from collections import Counter
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

# Tokenizing words from all movie descriptions
# Use pg34_df instead of df
all_words = " ".join(pg34_df['description'].dropna().astype(str)).lower().split()
filtered_words = [word for word in all_words if word not in stop_words and len(word) > 2]

# Get the most common words
word_freq = Counter(filtered_words)
most_common_words = word_freq.most_common(20)

# Plot the most common words
plt.figure(figsize=(10, 5))
sns.barplot(x=[word[1] for word in most_common_words], y=[word[0] for word in most_common_words], palette='viridis')
plt.xlabel("Frequency")
plt.ylabel("Words")
plt.title("Top 20 Most Frequent Words in Movie Descriptions") # Changed title for clarity
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <ipython-input-11-8f0c851440d4>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=[word[1] for word in most_common_words], y=[word[0] for word in most_common_words], palette='viridis')

# %%
import tensorflow as tf
model.save('my_rnn_model.keras')

# %%
import tensorflow as tf
model = tf.keras.models.load_model('my_rnn_model.keras')

# %%
def predict_sentiment(text):
    sequence = tokenizer.texts_to_sequences([text])
    padded = pad_sequences(sequence, maxlen=max_len, padding='post', truncating='post')
    prediction = model.predict(padded)[0][0]
    return prediction

# %%
sample_text = "A gripping and emotional drama with outstanding performances."
predicted_sentiment = predict_sentiment(sample_text)

print(f"Predicted Sentiment Score: {predicted_sentiment}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# Predicted Sentiment Score: 0.5108729600906372

# %%
review_text = "Any scene setting set on the college in the movie is so boring to watch on screen. The climax was the only passable thing in the film, as it focused on the characters' emotions. I was yawning and struggling to even stay awake during this film."
predicted_sentiment = predict_sentiment(review_text)
print(f"Predicted Sentiment Score: {predicted_sentiment}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Predicted Sentiment Score: 0.6968454122543335

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences

def predict_sentiment(text, tokenizer, model, max_len=100):
    sequence = tokenizer.texts_to_sequences([text])
    padded = pad_sequences(sequence, maxlen=max_len, padding='post', truncating='post')
    prediction = model.predict(padded)[0][0]
    return prediction

# Load the trained model
model = tf.keras.models.load_model('my_rnn_model.keras')

# Example usage
positive_reviews = [
    "Insidious : The Red Door Was A Mesmerizing Moving Picture. Very Graphical And Entertaining...",
    "In short, a good astral, I liked the continuation and completion of this story...",
    "I think this movie was a well executed end for the insidious series..."
]

negative_reviews = [
    "Any scene setting set on the college in the movie is so boring to watch on screen...",
    "One of the worst horror movies ever made...",
    "Insidious: The Red Door is a hot mess attempting to shoehorn in a plot..."
]

# Predict sentiment for positive reviews
for review in positive_reviews:
    score = predict_sentiment(review, tokenizer, model)
    print(f"Review: {review[:50]}...\nPredicted Sentiment Score: {score}\n")

# Predict sentiment for negative reviews
for review in negative_reviews:
    score = predict_sentiment(review, tokenizer, model)
    print(f"Review: {review[:50]}...\nPredicted Sentiment Score: {score}\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Review: Insidious : The Red Door Was A Mesmerizing Moving ...
# Predicted Sentiment Score: 0.538628339767456
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Review: In short, a good astral, I liked the continuation ...
# Predicted Sentiment Score: 0.5923980474472046
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Review: I think this movie was a well executed end for the...
# Predicted Sentiment Score: 0.5114220976829529
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Review: Any scene setting set on the college in the movie ...
# Predicted Sentiment Score: 0.3354867696762085
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Review: One of the worst horror movies ever made......
# Predicted Sentiment Score: 0.5023261904716492
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Review: Insidious: The Red Door is a hot mess attempting t...
# Predicted Sentiment Score: 0.5158392190933228
